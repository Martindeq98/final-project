# %% [markdown]
# # Benchmarks
# This notebook computes benchmarks for the following methods:
# - If $n \leq 5$, do exhaustive as well.
# - OMP
# - NOTEARS
#
# Furthermore, this notebook provides the artificial data, and how to generate it. The code for the methods is imported using a module.

# %%
# standard libraries
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append("..")
import helper.helper as h
import helper.methods as m

from importlib import reload  # Python 3.4+

# %%
# reload helper and methods for when things change
reload(m);
reload(h);

# %% [markdown]
# ### Generate data

# %%
## Number of dimensions, number of edges, number of samples
T, n, s = 100, 4, 10

### Coefficient matrix
## First approach: A is a DAG, no model mismatch
# A_true = h.generate_A(n, s, tril = False, low = 0.25, high = 0.25)

## Second approach: A is not necessarily a DAG, possible model mismatch
A_true = (np.array([0.0] * (n ** 2 - s) + [1.0] * s) * (2 * np.random.randint(0, 2, size=(n ** 2)) - 1) * np.random.uniform(low = 0.25, high = 0.35, size = n ** 2))

# shuffle for randomness
np.random.shuffle(A_true)

# reshape
A_true = A_true.reshape(n, n)

# set coefficients to be positive (else oscillating which does not make sense)
for i in range(len(A_true)):
    A_true[i][i] = np.abs(A_true[i][i])

## True permutation
P_true = np.random.permutation(np.identity(n))

## Datagenerating W
W_true = P_true.T @ A_true @ P_true
print(f"True W:\n{np.round(W_true, 2)}.\n")

## Generate series
X = h.generate_var_2(T, n, A_true, P_true)
plt.plot(X);
# Out:
# True W:
# [[ 0.26  0.28  0.28  0.31]
#  [ 0.    0.    0.28 -0.26]
#  [ 0.25  0.34  0.29  0.  ]
#  [ 0.    0.    0.28  0.  ]].

# %% [markdown]
# ### Possibly Save data

# %%
save = False
if save: h.save_data(X, W_true, "random_matrix", "All edges are between +- 0.25 - 0.50. Not all diagonal entries are positive. The generating W is no DAG.")

# %% [markdown]
# ### Possibly Load data

# %%
load = False
name = ""
if load:
    W_true, X, expl = load_data(name)
    print(f"Loaded {name}.\nExplation: {expl}.")

# %% [markdown]
# ### Lasso Regularization Approach

# %%
W_lasso, lambda = m._LASSO_LINGNAM(X)
print(f"W_ling:\n{np.round(W_lasso, 2)}.\n")
h.score(X, W_lasso, W_true, rounding = 10);

# %% [markdown]
# ### Lingnam Approach

# %%
W_ling, W_OLS = m._OLS_LINGNAM(X)
print(f"W_ling:\n{np.round(W_ling, 2)}.\n")
h.score(X, W_ling, W_true, rounding = 10);
# Out:
# W_ling:
# [[0.   0.   0.   0.34]
#  [0.   0.   0.   0.  ]
#  [0.   0.35 0.   0.  ]
#  [0.   0.   0.34 0.  ]].
#
# True Positive Rate: 0.3.
# True Negative Rate: 1.0.
# False Prediction Rate: 0.0
# Accuracy: 0.5625.
# Mean Squared Error: 4.434825047
# R-Squared: 0.0957832123

# %% [markdown]
# ### OMP Approach

# %%
W_omp, edges, scores = m._OMP(X, get_order = True)
print(f"W_OMP:\n{np.round(W_omp, 2)}.\n")
h.score(X, W_omp, W_true, rounding = 10);
# Out:
# W_OMP:
# [[ 0.27  0.2   0.25  0.34]
#  [ 0.    0.09  0.27 -0.21]
#  [ 0.    0.    0.19  0.  ]
#  [ 0.    0.    0.34  0.01]].
#
# True Positive Rate: 0.8.
# True Negative Rate: 0.6666666667.
# False Prediction Rate: 0.2
# Accuracy: 0.75.
# Mean Squared Error: 4.1030237704
# R-Squared: 0.1640892286

# %% [markdown]
# ### Exhaustive Approach

# %%
W_exh = m._Exh(X)
print(f"W_EXH:\n{np.round(W_exh, 2)}.\n")
h.score(X, W_exh, W_true, rounding = 10);
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 521.67it/s]
# W_EXH:
# [[ 0.27  0.19  0.3   0.29]
#  [ 0.   -0.02  0.    0.  ]
#  [ 0.    0.35  0.25  0.  ]
#  [ 0.   -0.06  0.34 -0.02]].
#
# True Positive Rate: 0.7.
# True Negative Rate: 0.5.
# False Prediction Rate: 0.3
# Accuracy: 0.625.
# Mean Squared Error: 4.0587937289
# R-Squared: 0.1725298583

# %%
threshold, step_size = 0.0, 0.001

W_notears = m._notears(X, loss_type="l2-var", lambda1=0.00000001, verbose = True)

print(f"W_notears before thresholding, not necessarily a DAG:\n{np.round(W_notears, 2)}.\n")

# fix dag_ness
while not h.is_dag(W_notears):
    threshold += step_size
    W_notears[np.abs(W_notears) < threshold] = 0
    
print(f"W_notears after smallest threshold {round(threshold, 2)} such that we have a DAG:\n{np.round(W_notears, 2)}.\n")

h.score(X, W_notears, W_true, rounding = 10);
# Out:
# Terminating: value for h: 8.744822393147444e-05, rho: 9.999999999999999e+25.
# Gradient of h:
# [[ 4.85e-01  6.90e-07  3.13e-04  2.86e-06]
#  [ 4.35e-05 -3.35e-02  8.48e-03 -4.75e-05]
#  [ 1.14e-03  3.85e-03  3.81e-01 -2.32e-04]
#  [ 5.20e-05 -2.14e-04  1.23e-05  7.65e-03]].
#
# Augm. Lagr. function value: 1.1470787803153948e+18
# Gradient:
# [ 8.48e+21  1.21e+16  5.48e+18  5.01e+16  7.61e+17 -5.85e+20  1.48e+20
#  -8.32e+17  1.99e+19  6.74e+19  6.66e+21 -4.05e+18  9.09e+17 -3.75e+18
#   2.16e+17  1.34e+20 -8.48e+21 -1.21e+16 -5.48e+18 -5.01e+16 -7.61e+17
#   5.85e+20 -1.48e+20  8.32e+17 -1.99e+19 -6.74e+19 -6.66e+21  4.05e+18
#  -9.09e+17  3.75e+18 -2.16e+17 -1.34e+20].
#
# W_notears before thresholding, not necessarily a DAG:
# [[0.   0.   0.   0.34]
#  [0.   0.   0.27 0.  ]
#  [0.   0.35 0.   0.  ]
#  [0.   0.   0.34 0.  ]].
#
# W_notears after smallest threshold 0.27 such that we have a DAG:
# [[0.   0.   0.   0.34]
#  [0.   0.   0.   0.  ]
#  [0.   0.35 0.   0.  ]
#  [0.   0.   0.34 0.  ]].
#
# True Positive Rate: 0.3.
# True Negative Rate: 1.0.
# False Prediction Rate: 0.0
# Accuracy: 0.5625.
# Mean Squared Error: 4.4348241828
# R-Squared: 0.0957833835
