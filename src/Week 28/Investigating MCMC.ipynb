# %% [markdown]
# Visualise the solution path of MCMC as a function of the current iteration number. Hopefully, we see that it is almost perfect very soon already.
#
# Perhaps modify it? We can augment it using LASSO, or instead of a random walk, we pick the "best" transposition of the p (p - 1) / 2 ones.
#
# Try to find a situation where we are stuck in a local optimum, as simple as possible.

# %%
import matplotlib.pyplot as plt
import numpy as np
# x = np.linspace(0, 2 * np.pi, 100)
# y = np.sin(x)
# plt.plot(x, y)
# plt.show()

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-1.1, 1.1)

# %%
def animate(frame_num):
    print(x)
    y = np.sin(x + 2*np.pi * frame_num/100)
    line.set_data((x, y))
    return line

# %%
line, = ax.plot([])     # A tuple unpacking to unpack the only plot
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(-1.1, 1.1)
anim = FuncAnimation(fig, animate, frames=200, interval=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

plt.axis([0, 10, 0, 1])
plt.show()

for i in range(100):
    y = np.random.random()
    plt.scatter(i, y)
    plt.pause(0.05)
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
