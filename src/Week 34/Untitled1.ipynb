# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.genfromtxt('SimNet.txt',delimiter=',')
print(np.shape(X))

# 5 nodes, 50 timeseries of length 200.
n_nodes = 5
n_ts    = 50
T       = 200
# Out:
# (10000, 5)

# %%
i = 5
plt.plot(X[T * i - 50: T * (i + 1) - 50, 0])

# %%
X_1 = X[0:200]
plt.plot(X_1)

# %%
print(np.linalg.inv(X_1[:-1].T @ X_1[:-1]) @ X_1[:-1].T @ X_1[1:])
print(np.linalg.inv(X[:-1].T @ X[:-1]) @ X[:-1].T @ X[1:])
# Out:
# [[ 0.44042797  0.04807933  0.00585797  0.01804335  0.03595724]
#  [-0.05201507  0.44564767 -0.00091551  0.05189189 -0.09438841]
#  [ 0.14384998  0.05623871  0.35655787 -0.0657556   0.12498985]
#  [-0.09130351 -0.10526368  0.0626654   0.32621775 -0.11444743]
#  [ 0.10237169  0.10132791  0.01574355  0.09418079  0.35515895]]
# [[ 0.34548723  0.05234228  0.00677524 -0.01526246  0.0566393 ]
#  [ 0.0291726   0.32708615  0.04936813  0.01544031 -0.00250978]
#  [ 0.02622576  0.03823665  0.3159065   0.04355792  0.01011585]
#  [-0.02442887 -0.00438862  0.01885318  0.31380631  0.06267067]
#  [ 0.03233018 -0.00193117 -0.0090545   0.02008673  0.2951019 ]]
