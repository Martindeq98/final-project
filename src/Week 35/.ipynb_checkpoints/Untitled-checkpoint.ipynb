# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib

matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 8
})

matplotlib.rcParams['axes.unicode_minus'] = False

# %%
n = 2500
#np.random.seed(seed = 1)
plt.figure(figsize = (3.0, 2.5))
plt.ylabel(r"$Y$")
plt.xlabel(r"$X$")
plt.title(r"Model with Gaussian noise where $Y = 0.8X$")
X = np.random.normal(0, 1, n)
Y = 0.8 * X + np.random.normal(0, 0.6, n)
#help(plt.scatter)
plt.scatter(X, Y, marker = "o", s = 12)
plt.savefig("scatter_gauss_1.pgf")
print(np.round((np.mean(X), np.cov(X), np.mean(Y), np.cov(Y)), 3))
# Out:
# [0.015 0.982 0.001 0.99 ]

# %%
Z = np.random.multivariate_normal(np.zeros(2), np.cov(X, Y), 100000)
plt.scatter(Z.T[0], Z.T[1], s = 10)

# %%
# np.random.seed(seed = 1)
plt.figure(figsize = (3.0, 2.5))

plt.ylabel(r"$Y$")
plt.xlabel(r"$X$")
plt.title(r"Model with with Gaussian noise where $X = 0.8Y$")

Y = np.random.normal(0, 1, n)
X = 0.8 * Y + np.random.normal(0, 0.6, n)

plt.scatter(X, Y, s = 12)
plt.savefig("scatter_gauss_2.pgf")
print(np.round((np.mean(X), np.cov(X), np.mean(Y), np.cov(Y)), 3))
# Out:
# [-0.019  1.01  -0.016  0.995]

# %%
# n = 2500
plt.figure(figsize = (3.0, 2.5))

plt.ylabel(r"$Y$")
plt.xlabel(r"$X$")
plt.title(r"Model with uniform noise where $Y = 0.8X$")

plt.xlim(-2, 2)
plt.ylim(-3, 3)
a = np.sqrt(3)
b = 0.6 * np.sqrt(3)
X = np.random.uniform(-a, a, n)
Y = 0.8 * X + np.random.uniform(-b, b, n)
plt.scatter(X, Y, s = 10)
print(np.round((np.mean(X), np.cov(X), np.mean(Y), np.cov(Y)), 3))

plt.savefig("scatter_unif_1.pgf")
# x = np.linspace(min(X), max(X), 100)
# plt.plot(x, x * 0.8, color = 'black', label = "Y = 0.8X")

# x = np.linspace(min(X), max(X), 100)
# plt.plot(x, x / 0.8, color = 'red', label = "X = 0.8Y")

# plt.legend()
# Out:
# [-0.002  1.013  0.     0.962]

# %%
n = 5000

a = np.sqrt(3)
b = 0.6 * np.sqrt(3)
X = np.random.uniform(-a, a, n)
Y = 0.8 * X + np.random.uniform(-b, b, n)

print(1 / n * np.linalg.norm(X - (Y - 0.8 * X)) ** 2)
print(1 / n * np.linalg.norm(Y - (X - 0.8 * Y)) ** 2)
# Out:
# 1.309575596220085
# 1.3974224680617457

# %%
n = 2500
plt.figure(figsize = (3.0, 2.5)) 

plt.ylabel(r"$Y$")
plt.xlabel(r"$X$")
plt.title(r"Model with uniform noise where $Y = 0.8X$")

plt.xlim(-2, 2)
plt.ylim(-3, 3)
plt.scatter(X, Y, s = 12)

x = np.linspace(min(X), max(X), 100)
plt.plot(x, x / 0.8, color = 'red', label = "X = 0.8Y", linewidth = 3)

x = np.linspace(min(X), max(X), 100)
plt.plot(x, x * 0.8, color = 'black', label = "Y = 0.8X", linewidth = 3)

plt.legend()
plt.savefig("scatter_unif_1_lines.pgf")
plt.show()

plt.figure(figsize = (3.0, 2.5))
plt.xlabel(r"$X$")
plt.ylabel(r"Residual: $Y - 0.8X$")
plt.title(r"Residuals when assuming $X \rightarrow Y$")
plt.scatter(X, Y - 0.8 * X, s = 12)
plt.savefig("scatter_unif_resid_1.pgf")
plt.show()

plt.figure(figsize = (3.0, 2.5))
plt.xlabel(r"Residual: $X - 0.8Y$")
plt.ylabel(r"$Y$")
plt.title(r"Residuals when assuming $Y \rightarrow X$")
plt.savefig("scatter_unif_resid_2.pgf")
plt.scatter(X - 0.8 * Y, Y, s = 12)
# Out:
# C:\Users\s165048\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Matplotlib is currently using pgf, which is a non-GUI backend, so cannot show the figure.
# C:\Users\s165048\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:28: UserWarning: Matplotlib is currently using pgf, which is a non-GUI backend, so cannot show the figure.

# %%
plt.ylabel("Y")
plt.xlabel("X")
plt.title(r"Scatter plot of the linear model with uniform noise where $X = 0.8Y$")

plt.xlim(-3, 3)
plt.ylim(-2, 2)

Y = np.random.uniform(-a, a, n)
X = 0.8 * Y + np.random.uniform(-b, b, n)
plt.scatter(X, Y, s = 10)

x = np.linspace(min(X), max(X))
# plt.plot(x, x / 0.8, color = 'black', label = "X = 0.8Y")
plt.savefig("scatter_unif_2.pgf")

print(np.round((np.mean(X), np.cov(X), np.mean(Y), np.cov(Y)), 3))
# Out:
# [-0.013  0.978 -0.011  0.984]

# %%
print(1 / (X.T @ X) * (X.T@ Y))
print(1 / (Y.T @ Y) * (Y.T@ X))
# Out:
# 0.787775733549028
# 0.8096313816766283
