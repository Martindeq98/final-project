# %%
# import standard libraries
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# import helper methods
import sys
sys.path.append("..")
import helper.helper as h
import helper.methods as m

# reload helper for reloading modules
from importlib import reload

# %%
### Alternatively, load the data. Both are equivalent.
W, X, expl = h.load_data("X_s5_n100_T3_LASSO_example_3");
print(np.shape(W))
# Out:
# (3, 3)

# %%
import matplotlib
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "xelatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 8
})

# %%
## Plot series
fig = plt.figure(figsize = (5.5, 3))
fig.patch.set_alpha(0)
plt.xlabel(r"Timestep $t$")
plt.ylabel(r"Value")
plots = plt.plot(X); 
plt.legend(plots, [r"$X_1$", r"$X_2$", r"$X_3$"], loc = 4);
plt.savefig('figure LASSO 3D.pgf')
