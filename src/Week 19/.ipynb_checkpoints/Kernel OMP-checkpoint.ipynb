# %%
import matplotlib.pyplot as plt
import numpy as np

# generate SEM
import sys
sys.path.append("..")
from sklearn.linear_model import OrthogonalMatchingPursuit
from timeit import default_timer as timer
from notears.notears.notears import linear
from notears.notears.notears import utils
import helper.helper as h
import helper.methods as m

from importlib import reload  # Python 3.4+

# %% [markdown]
# ### Generate VAR data

# %%
np.random.seed(seed = 123456)

## Number of dimensions, number of edges, number of samples
T, n, s = 50, 6, 8

N = int(n * (n + 1) / 2)

### Coefficient matrix
## First approach: A is a DAG, no model mismatch
A_true = h.generate_A(n, s, tril = False, low = 0.30, high = 0.70)

# set coefficients to be positive (else oscillating which does not make sense)
for i in range(len(A_true)):
    A_true[i][i] = 0.4 # np.abs(A_true[i][i])

s = len(A_true.flatten().nonzero()[0])

## True permutation
P_true = np.identity(n) 

## Datagenerating W
W_true = P_true.T @ A_true @ P_true
print(f"True W:\n{np.round(W_true, 2)}.\n")

## Generate series
X = h.generate_var_2(T, n, A_true, P_true)
plt.figure(figsize = (12, 4))
plt.plot(X);
# Out:
# True W:
# [[ 0.4   0.    0.    0.    0.    0.  ]
#  [ 0.    0.4   0.    0.    0.    0.  ]
#  [ 0.52  0.    0.4   0.    0.    0.  ]
#  [ 0.    0.    0.    0.4   0.    0.  ]
#  [ 0.    0.    0.45  0.45  0.4   0.  ]
#  [-0.48  0.48  0.    0.   -0.43  0.4 ]].

# %% [markdown]
# ### Generate Linear Regression Data

# %%
def normalize(X): return X / np.linalg.norm(X, 2)

# generate data
n, T = 3, 100
w = range(n)
X = np.random.rand(T, n)
plt.plot(X)

#X_norm = X.copy()
#for i in range(n):
#    X_norm[:, i] = normalize(X_norm[:, i])

#X = X_norm.copy()
Y = X @ w #+ np.random.rand(T)

# %% [markdown]
# ### Regular OMP

# %%
def OMP(X, Y):
    
    # start timer
    start = timer()
    
    # initialize Lambda, betas
    r, Lambda, Omega, betas = Y.copy(), set(), set(), np.zeros(n)
    
    # for each of the n possible coefficients
    for i in range(n):
        
        # compute gains
        gains = np.abs([r.T @ x for x in X.T])
        
        # append best atom to Lambda
        Lambda.add(np.argmax(gains))
        idx = np.array(list(Lambda))
        
        # if so, calculate new betas using only atoms in F
        Omega = X[:, idx]
        betas[idx] = np.linalg.inv(Omega.T @ Omega) @ Omega.T @ Y
        print(np.round(betas, 3))
        
        # compute new residual
        r = Y - X @ betas
    
    # end timer
    end = timer()
    
    # print result + timing
    # print(np.round(betas, 3))
    # print(f"Time taken: {round(1000 * (end - start))} milliseconds.")
    
    return betas
    
OMP(X, Y);

# KOMP(RBF_Psi, RBF_K, theta)
# Out:
# [-0.204  0.   ]
# [-0.19  -0.057]

# %% [markdown]
# ### Kernels

# %%
def RBF(i, j):
    return np.exp(-np.linalg.norm(i - j, 2) ** 2 / 2)

def L(i, j):
    return i.T @ j

# %%
L_Psi = np.zeros((n, n))
L_K = np.zeros(n)

for i, X_i in enumerate(X.T):
    for j, X_j in enumerate(X.T):
        L_Psi[i, j] = L(X_i, X_j)

for i, X_i in enumerate(X.T):
    L_K[i] = L(X_i, Y)
    
theta = L(Y, Y)

# %%
RBF_Psi = np.zeros((n, n))
RBF_K = np.zeros(n)

for i, X_i in enumerate(X.T):
    for j, X_j in enumerate(X.T):
        RBF_Psi[i, j] = RBF(X_i, X_j)

for i, X_i in enumerate(X.T):
    RBF_K[i] = RBF(X_i, Y)
    
RBF_theta = RBF(Y, Y)

# %%
# X_norm = np.sum(X ** 2, axis = -1)
# Psi = np.exp(-(X_norm[:,None] + X_norm[None,:] - 2 * np.dot(X, X.T)) / 2)
# print(np.shape(Psi))

# K = np.exp(-(X_norm[:,None] + X_norm[None,:] - 2 * np.dot(X, X.T)) / 2)
# print(K)

# %% [markdown]
# ### K-OMP, Precomputed Kernels

# %%
def K_OMP_PRECOMP(Psi, K, theta):
    
    # start timer
    start = timer()
    
    # initialize Lambda, betas
    Lambda, betas = set(), np.zeros(n)
    
    # for each coefficient
    for i in range(n):
        
        # compute gains
        gains = [k - (betas[list(Lambda)].T @ Psi[i, list(Lambda)]) for i, k in enumerate(K)]
    
        # append best atom to Lambda
        Lambda.add(np.argmax(gains))
        idx = np.array(list(Lambda))
        
        # if so, calculate new betas using only atoms in F
        betas[idx] = np.linalg.inv(Psi[idx[:, None], idx[None, :]]) @ K[idx]
        print(np.round(betas, 2))
        
        # compute residual
        # print("Residual Squared:", round(theta - K.T @ betas, 2))
    
    # stop timer
    end = timer()
    
    # print(np.round(betas, 5))
    # print(f" {round(1000 * (end - start))} milliseconds.")
    
    return betas
    
K_OMP_PRECOMP(L_Psi, L_K, theta);
# Out:
# [0.   0.   2.72]
# [0. 1. 2.]
# [0. 1. 2.]

# %% [markdown]
# ### K-OMP, Kernel not precomputed

# %%
def K_OMP(X, y):
    
    # start timer
    start = timer()
    
    # compute kernel
    Psi = X.T.dot(X)
    K = X.T.dot(y)
    theta = y.T.dot(y)
    
    # initialize Lambda, betas
    Lambda, betas = set(), np.zeros(n)
    
    # for each possible coefficient
    for i in range(n):
        
        # compute gains
        gains = np.abs([k - (betas[list(Lambda)].T @ Psi[i, list(Lambda)]) for i, k in enumerate(K)])
        
        # append best atom to Lambda
        Lambda.add(np.argmax(gains))
        idx = np.array(list(Lambda))

        # if so, calculate new betas using only atoms in F
        betas[idx] = np.linalg.inv(Psi[idx[:, None], idx[None, :]]) @ K[idx]
        print(np.round(betas, 3))
        
        # compute residuals
        # print("Residual Squared:", round(theta - K.T @ betas, 2))
    
    # stop timer
    end = timer()
    
    # print(f"{round(1000 * (end - start))}", end = "\t")
    
    return betas

K_OMP(X, Y);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-810-9306d150b364> in <module>
#      36     return betas
#      37
# ---> 38 K_OMP(X, Y);
#
# <ipython-input-810-9306d150b364> in K_OMP(X, y)
#       6     # compute kernel
#       7     Psi = X.T.dot(X)
# ----> 8     K = X.T.dot(y)
#       9     theta = y.T.dot(y)
#      10
#
# ValueError: shapes (6,50) and (100,) not aligned: 50 (dim 1) != 100 (dim 0)

# %% [markdown]
# ### Verifications

# %%
# generate data
X = h.generate_var_2(T, np.shape(A_true)[0], A_true, P_true)

# get dimensions
T, n = np.shape(X)

# run all three methods, compare
# OMP with no kernel
OMP(X[:-1], X[1:, 0])
print()

# OMP with linear kernel
K_OMP(X[:-1], X[1:, 0])
print()

# orthogonal matching pursuit implementation of scipi
for i in range(1, n + 1):
    fit = OrthogonalMatchingPursuit(n_nonzero_coefs = i, normalize = False, fit_intercept = False)
    print(np.round(fit.fit(X[:-1], X[1:, 0]).coef_, 3))
# Out:
# [0.619 0.    0.    0.    0.    0.   ]
# [0.49  0.    0.533 0.    0.    0.   ]
# [ 0.36   0.     0.593  0.     0.    -0.572]
# [ 0.373  0.     0.646  0.    -0.131 -0.636]
# [ 0.398  0.     0.674 -0.061 -0.123 -0.632]
# [ 0.4    0.035  0.662 -0.056 -0.111 -0.634]
#
# [0.619 0.    0.    0.    0.    0.   ]
# [0.49  0.    0.533 0.    0.    0.   ]
# [ 0.36   0.     0.593  0.     0.    -0.572]
# [ 0.373  0.     0.646  0.    -0.131 -0.636]
# [ 0.398  0.     0.674 -0.061 -0.123 -0.632]
# [ 0.4    0.035  0.662 -0.056 -0.111 -0.634]
#
# [0.619 0.    0.    0.    0.    0.   ]
# [0.49  0.    0.533 0.    0.    0.   ]
# [ 0.36   0.     0.593  0.     0.    -0.572]
# [ 0.373  0.     0.646  0.    -0.131 -0.636]
# [ 0.398  0.     0.674 -0.061 -0.123 -0.632]
# [ 0.4    0.035  0.662 -0.056 -0.111 -0.634]

# %% [markdown]
# ### Matrix K-OMP, Kernel not precomputed

# %%
def MATRIX_KOMP(X, Y, verbose = False):

    start = timer()
    
    # intialize F
    F = np.full((n, n), False)
    
    Psi = X.T.dot(X)
    K = X.T.dot(Y)
    Theta = [y.T.dot(y) for y in Y.T]
    
    # initialize Lambda, betas
    Lambda, idx, betas = [[] for _ in range(n)], [], np.zeros((n, n))
    
    # for each possible coefficient
    for i in range(n ** 2):    
    
        # compute gains
        gains = np.abs([k - betas.T @ Psi[i, :] for i, k in enumerate(K)])
        
        # append best atom to Lambda
        row, col = np.argmax(gains) // n, np.argmax(gains) % n
        Lambda[col].append(row)
        
        # update only column col, use indices of 
        idx = Lambda[col]
        Psi_F = Psi[np.array(idx)[:, None], np.array(idx)[None, :]]
        
        # update betas        
        betas[np.array(idx)[:, None], col] = np.linalg.inv(Psi_F) @ K[np.array(idx)[:, None], col]
    
        # compute residual
        # print(f"Residual Squared: {np.round([Theta[i] - K.T[i, :] @ betas[:, i] for i in range(n)])}.\n\n")
    
        if verbose:
            print(f"Iteration {i + 1}.\n")
            print(f"Gains:\n{np.round(gains)}.\n")
            print(f"Beta_{i + 1}:\n{np.round(betas, 1)}.\n")
            
    end = timer()
    
    print(f"{round(1000 * (end - start))}", end = "\t")
    
    return betas

# generate data
MATRIX_KOMP(X[:-1], X[1:]);
# Out:
# 11

# %%
# get X large
X_large = np.kron(np.eye(n, dtype=float), X[:-1])

# Stack all X on top of each other for y
y_large = X[1:].T.reshape((T - 1) * n, 1)
    
for i in range(1, n ** 2 + 1):
    fit = OrthogonalMatchingPursuit(n_nonzero_coefs = i, fit_intercept = False, normalize = True)
    # print(np.round(fit.fit(X_large, y_large).coef_.reshape(n, n).T, 1))

# %% [markdown]
# ### DAG-K-OMP

# %%
def MATRIX_KOMP(X, Y, verbose = False):

    start = timer()
    
    # intialize F, forbidden set
    F = np.array([])
    
    Psi = X.T.dot(X)
    K = X.T.dot(Y)
    Theta = [y.T.dot(y) for y in Y.T]
    
    # initialize Lambda, betas
    Lambda, idx, betas = [[] for _ in range(n)], [], np.zeros((n, n))
    
    # for each possible coefficient
    for i in range(n ** 2):    
    
        # compute gains
        gains = np.abs([k - betas.T @ Psi[i, :] for i, k in enumerate(K)])
        
        # set forbidden set to -1, impossible to pick
        gains[F] = -1 * np.ones(len(F))
        
        # append best atom to Lambda
        row, col = np.argmax(gains) // n, np.argmax(gains) % n
        Lambda[col].append(row)
        
        # check if we have a DAG
        if h.is_dag(np.array(Lambda)): 
            # update only column col, use indices of 
            idx = Lambda[col]
            Psi_F = Psi[np.array(idx)[:, None], np.array(idx)[None, :]]
        
            # update betas        
            betas[np.array(idx)[:, None], col] = np.linalg.inv(Psi_F) @ K[np.array(idx)[:, None], col]
    
            # compute residual
            # print(f"Residual Squared: {np.round([Theta[i] - K.T[i, :] @ betas[:, i] for i in range(n)])}.\n\n")
        
        else:
            F.append(np.argmax(gains))
            Lambda[col].remove(row)
        

    
        if verbose:
            print(f"Iteration {i + 1}.\n")
            print(f"Gains:\n{np.round(gains)}.\n")
            print(f"Beta_{i + 1}:\n{np.round(betas, 1)}.\n")
            
    end = timer()
    
    print(f"{round(1000 * (end - start))}", end = "\t")
    
    return betas

# generate data
MATRIX_KOMP(X[:-1], X[1:]);
# Out:
# [list([0]) list([]) list([]) list([]) list([]) list([])]
# C:\Users\s165048\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# C:\Users\s165048\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-850-08cbcfd86d21> in <module>
#      51
#      52 # generate data
# ---> 53 MATRIX_KOMP(X[:-1], X[1:]);
#
# <ipython-input-850-08cbcfd86d21> in MATRIX_KOMP(X, Y, verbose)
#      26
#      27         # check if we have a DAG
# ---> 28         if h.is_dag(np.array(Lambda)):
#      29             print("a")
#      30
#
# ~\OneDrive - TU Eindhoven\QuinceyFinalProject\final-project\src\helper\helper.py in is_dag(W_input)
#     223     W = W_input.copy()
#     224     # remove diagonal entries
# --> 225     np.fill_diagonal(W, 0)
#     226
#     227     order, old_order = [], list(range(n))
#
# <__array_function__ internals> in fill_diagonal(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python36\site-packages\numpy\lib\index_tricks.py in fill_diagonal(a, val, wrap)
#     857     """
#     858     if a.ndim < 2:
# --> 859         raise ValueError("array must be at least 2-d")
#     860     end = None
#     861     if a.ndim == 2:
#
# ValueError: array must be at least 2-d
